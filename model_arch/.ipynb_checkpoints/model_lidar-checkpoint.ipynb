# %%
# Modelling for Lidar data
# Lidar model architecture

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# ===========================================
# Required for memory usage in some RTX 2k,3k series

physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)

## Memory settings
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True # dynamically grow the memory used on the GPU
config.log_device_placement = True # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
## ---- end Memory setting ----

# Fusion: weighting
class c_fusion_wt (layers.Layer):
    def __init__(self,**kwargs):
        super(c_fusion_wt, self).__init__(**kwargs)
    
    def build (self, input_shape):
        self.w=self.add_weight(shape=(1,), initializer="zero", trainable=True,name='weight') 
        
    def call(self, layer_1):
        return layer_1*self.w 

    def get_config(self):
        config = super(c_fusion_wt, self).get_config()
        return config
# Out:
# 2024-06-13 18:26:03.807152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-13 18:26:03.811290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-13 18:26:03.811416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-13 18:26:03.922128: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %%
#============================================
img_size = (384,1248)
ldr_size= (384,1248) # projected lidar image size
class_num = 2 # model output channels


def get_lidar_model(img_size, num_classes):
    inputs_img = keras.Input(shape=img_size + (3,), name='lidar')
    
    # Encoder
    #B1
    x = layers.ZeroPadding2D(padding=1, name='Block1_lidar_zp')(inputs_img)
    x = layers.Conv2D(32, 4, strides=2, activation='elu', name='Block1_lidar_conv')(x)
    # Add more encoder blocks as needed
    #B2: Block 2
    x=layers.ZeroPadding2D(padding=1,name='Block2_lidar_zp')(x)
    x=layers.Conv2D(32,3,strides=1,activation='elu',name='Block2_lidar_conv')(x) 

    #B3: Block 3
    x=layers.ZeroPadding2D(padding=1,name='Block3_lidar_zp')(x)
    x=layers.Conv2D(64,4,strides=2,activation='elu', name='Block3_lidar_conv')(x)  
    
    #B4: Block 4
    x=layers.ZeroPadding2D(padding=1, name='Block4_lidar_zp')(x)
    x=layers.Conv2D(64,3,strides=1,activation='elu', name='Block4_lidar_conv')(x) 

    #B5: Block 5
    x=layers.ZeroPadding2D(padding=1,name='Block5_lidar_zp')(x)
    x=layers.Conv2D(128,4,strides=2,activation='elu', name='Block5_lidar_conv')(x) 
    
    #B5: Block 51
    x=layers.ZeroPadding2D(padding=1, name='Block51_lidar_zp')(x)
    x=layers.Conv2D(128,3,strides=1,activation='elu', name='Block52_lidar_conv')(x) 

    #B5: Block 52
    x=layers.ZeroPadding2D(padding=1,name='Block552_lidar_zp')(x)
    x=layers.Conv2D(256,4,strides=2,activation='elu', name='Block552_lidar_conv')(x) 


    # Context module
    #B6: Block 6
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(1,1),activation='elu', name='Block6_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block6_lidar_dp')(x)

    #B7: Block 7
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(1,1),activation='elu', name='Block7_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block7_lidar_dp')(x)

    #B8: Block 8
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(1,2),activation='elu', name='Block8_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block8_lidar_dp')(x)

    #B9: Block 9
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(2,4),activation='elu', name='Block9_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block9_lidar_dp')(x)

    #B10: Block 10
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(4,8),activation='elu', name='Block10_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block10_lidar_dp')(x)

    #B11: Block 11
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(8,16),activation='elu', name='Block11_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block11_lidar_dp')(x)

    #B12: Block 12
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(16,32),activation='elu', name='Block12_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block12_lidar_dp')(x)

    #B13: Block 13
    x=layers.Conv2D(256,3,padding="same",dilation_rate=(1,1),activation='elu', name='Block13_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block13_lidar_dp')(x)

    #B14: Block 14
    x=layers.Conv2D(256,1,padding="same",activation='elu', name='Block14_lidar_conv')(x)
    x=layers.Dropout(0.25, name='Block14_lidar_dp')(x)

    # Decoder
    #B15: Block 15
    x=layers.Conv2DTranspose(128,4,strides=2,activation='elu', padding='same', name='Block15_lidar_convtp')(x)

    #B16: Block 16
    x=layers.ZeroPadding2D(padding=1,name='Block16_lidar_zp')(x)
    x=layers.Conv2D(128,3,strides=1,activation='elu', name='Block16_lidar_conv')(x)
    
    #B17: Block 162
    x=layers.Conv2DTranspose(64,4,strides=2,activation='elu', padding='same', name='Block162_lidar_convtp')(x)

    #B18: Block 163
    x=layers.ZeroPadding2D(padding=1, name='Block163_lidar_zp')(x)
    x=layers.Conv2D(64,3,strides=1,activation='elu', name='Block163_lidar_conv')(x)

    #B17: Block 17
    x=layers.Conv2DTranspose(32,4,strides=2,activation='elu', padding='same', name='Block17_lidar_convtp')(x)

    #B18: Block 18
    x=layers.ZeroPadding2D(padding=1, name='Block18_lidar_zp')(x)
    x=layers.Conv2D(32,3,strides=1,activation='elu', name='Block18_lidar_conv')(x)

    #B19: Block 19
    x=layers.Conv2DTranspose(8,4,strides=2, activation='elu', padding='same', name='Block19_lidar_convtp')(x)

    #B20: Block 20
    x=layers.ZeroPadding2D(padding=1, name='Block20_lidar_zp')(x)
    x=layers.Conv2D(class_num,3,strides=1, name='Block20_lidar_conv')(x) 

    # Output layer
    output = layers.Conv2D(num_classes, 3, activation='softmax', padding='same', name='lidar_output')(x)

    # Define the lidar model
    lidar_model = keras.Model(inputs=inputs_img, outputs=output, name='lidar_model')
    return lidar_model

lidar_model = get_lidar_model(img_size, class_num)
lidar_model.save('lidar_model')
lidar_model.summary()
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2024-06-13 18:26:04.670015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-13 18:26:04.670139: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-13 18:26:04.670195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
